# %%
"""
epochs=60, batch=16 , imgsz=640 , lr0=0.01, lrf=0.01 , val=True, save=True,save_period=5, cache=True,device=0,optimizer='SGD'
"""

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
model = YOLO('yolov8s.pt')
model.train(data="G:/BRACU CSE/CSE428 Project/data.yaml" , epochs=25, lr0=0.01, lrf=0.01 ,optimizer='SGD',dropout=0.5)
# Out:
# New https://pypi.org/project/ultralytics/8.2.6 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.11.9 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191MiB)
# ...

# %%
# Load a model
model = YOLO('G:/BRACU CSE/CSE428 Project/runs/detect/train22/weights/last.pt')  # load a partially trained model

# Resume training
results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.2.6 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.5  Python-3.11.9 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191MiB)
# ...

# %%
model = YOLO('G:/BRACU CSE/CSE428 Project/runs/detect/train22/weights/best.pt')
validation_results = model.val(data='G:/BRACU CSE/CSE428 Project/data.yaml')
# Out:
# Ultralytics YOLOv8.2.5  Python-3.11.9 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning G:\BRACU CSE\CSE428 Project\Dataset\val\labels.cache... 723 images, 7 backgrounds, 7 corrupt: 100%|██████████| 723/723 [00:00<?, ?it/s]
# val: WARNING  G:\BRACU CSE\CSE428 Project\Dataset\val\images\2963.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     2.4172      3.0767      2.5756      1.5525]
# val: WARNING  G:\BRACU CSE\CSE428 Project\Dataset\val\images\2974.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     2.4172      3.0767      2.5756      1.5525]
# val: WARNING  G:\BRACU CSE\CSE428 Project\Dataset\val\images\2975.png: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     2.4172      3.0767      2.5756      1.5525]
# ...
